# %% [markdown]
# ### HuggingFace ChatModel

# %% [markdown]
# Import Libraries and HugginFace Inference API key

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os

load_dotenv()

os.environ["HUGGINGFACEHUB_API_TOKEN"] = os.getenv("HUGGINGFACEHUB_API_TOKEN")

# %% [markdown]
# Create ChatModel

# %%
llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    task="text-generation"
)

chat_model = ChatHuggingFace(llm=llm)

# %% [markdown]
# Invoke Model

# %%
result = chat_model.invoke("what is the capital of India")

print(result.content)
# Out:
# <think>
# Okay, the user is asking about the capital of India. That seems straightforward. Let me confirm the current capital - it's New Delhi.
# Hmm, should I just give the answer directly? Maybe add a bit more context since capital cities can sometimes be confused with the country name.
# The user might be a student doing homework, or perhaps a traveler planning a trip. Either way, clear information is key.
# I should mention that New Delhi is within the larger city of Delhi to avoid confusion. Some people might think the entire city is called New Delhi.
# Oh, and let's be precise about the status - it's both a union territory and the national capital. That covers administrative aspects.
# The response should be friendly but concise. No need for history lessons unless asked. Just the facts with a helpful tone.
# </think>
#
# The capital of India is **New Delhi**.
#
# *   **New Delhi** is specifically the area within the larger metropolis of **Delhi** that houses the central government institutions, including the Parliament, Rashtrapati Bhavan (President's residence), and many ministries.
# *   While often used interchangeably, **Delhi** refers to the entire National Capital Territory (a Union Territory), of which **New Delhi** is a distinct administrative district and the official capital.
#
# So, the official capital is **New Delhi**, located within the National Capital Territory of **Delhi**.
